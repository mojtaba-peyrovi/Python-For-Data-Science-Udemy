# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
college=pd.read_csv("college.csv")

# %%
college
# Out:
#                                   Unnamed: 0 Private   Apps  Accept  Enroll  \
# 0               Abilene Christian University     Yes   1660    1232     721
# 1                         Adelphi University     Yes   2186    1924     512
# 2                             Adrian College     Yes   1428    1097     336
# 3                        Agnes Scott College     Yes    417     349     137
# 4                  Alaska Pacific University     Yes    193     146      55
# 5                          Albertson College     Yes    587     479     158
# 6                    Albertus Magnus College     Yes    353     340     103
# 7                             Albion College     Yes   1899    1720     489
# 8                           Albright College     Yes   1038     839     227
# 9                  Alderson-Broaddus College     Yes    582     498     172
# 10                         Alfred University     Yes   1732    1425     472
# ...

# %%
sns.distplot(college['PhD'])
# Out:
# c:\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(college['PhD'], kde=False)
# Out:
# c:\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(college['Expend'], kde=False)
# Out:
# c:\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='Apps',y='Accept',data=college)
# Out:
# c:\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='Apps',y='Terminal',data=college, kind='hex')
# Out:
# c:\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='Apps',y='Terminal',data=college, kind='reg')
# Out:
# c:\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='Apps',y='Terminal',data=college, kind='kde')

# %%
sns.pairplot(college,hue='Private')

# %%
sns.countplot(x='Private',data=college)

# %%
college2 = college.drop(college.columns[6:],axis=1)

# %%
college2
# Out:
#                                   Unnamed: 0 Private   Apps  Accept  Enroll  \
# 0               Abilene Christian University     Yes   1660    1232     721
# 1                         Adelphi University     Yes   2186    1924     512
# 2                             Adrian College     Yes   1428    1097     336
# 3                        Agnes Scott College     Yes    417     349     137
# 4                  Alaska Pacific University     Yes    193     146      55
# 5                          Albertson College     Yes    587     479     158
# 6                    Albertus Magnus College     Yes    353     340     103
# 7                             Albion College     Yes   1899    1720     489
# 8                           Albright College     Yes   1038     839     227
# 9                  Alderson-Broaddus College     Yes    582     498     172
# 10                         Alfred University     Yes   1732    1425     472
# ...

# %%
college2.drop(college2.index[20:], inplace=True)

# %%
college2
# Out:
#                                  Unnamed: 0 Private  Apps  Accept  Enroll  \
# 0              Abilene Christian University     Yes  1660    1232     721
# 1                        Adelphi University     Yes  2186    1924     512
# 2                            Adrian College     Yes  1428    1097     336
# 3                       Agnes Scott College     Yes   417     349     137
# 4                 Alaska Pacific University     Yes   193     146      55
# 5                         Albertson College     Yes   587     479     158
# 6                   Albertus Magnus College     Yes   353     340     103
# 7                            Albion College     Yes  1899    1720     489
# 8                          Albright College     Yes  1038     839     227
# 9                 Alderson-Broaddus College     Yes   582     498     172
# 10                        Alfred University     Yes  1732    1425     472
# 11                        Allegheny College     Yes  2652    1900     484
# ...

# %%
college2_corr = college2.corr()

# %%
sns.heatmap(college2_corr,annot=True,cmap='coolwarm')

# %%
sns.lmplot(x='Apps',y='Accept',data=college,hue='Private',markers=['o','v'])

# %%
sns.pairplot(college2)
